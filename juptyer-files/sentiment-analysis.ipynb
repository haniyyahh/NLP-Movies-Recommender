# %%
import pandas as pd

movies = pd.read_csv("movies_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      top_k = None,
                      device = -1)
classifier("I love this!")
# Out:
# Device set to use cpu
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528691716492176},
#   {'label': 'neutral', 'score': 0.005764589179307222},
#   {'label': 'anger', 'score': 0.004419791977852583},
#   {'label': 'sadness', 'score': 0.002092393347993493},
#   {'label': 'disgust', 'score': 0.001611992483958602},
#   {'label': 'fear', 'score': 0.0004138525982853025}]]

# %%
classifier(movies["description"][0])
# Out:
# [[{'label': 'joy', 'score': 0.7927948832511902},
#   {'label': 'neutral', 'score': 0.15551497042179108},
#   {'label': 'disgust', 'score': 0.01860632374882698},
#   {'label': 'anger', 'score': 0.012162130326032639},
#   {'label': 'sadness', 'score': 0.010016023181378841},
#   {'label': 'surprise', 'score': 0.009432087652385235},
#   {'label': 'fear', 'score': 0.0014735726872459054}]]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
ids = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
movies = movies.dropna(subset=["description"])
movies = movies[movies["description"].str.strip() != ""]
movies = movies.reset_index(drop=True)
movies
# Out:
#             id                               name    date  \
# 0      1000001                             Barbie  2023.0
# 1      1000002                           Parasite  2019.0
# 2      1000003  Everything Everywhere All at Once  2022.0
# 3      1000004                         Fight Club  1999.0
# 4      1000005                         La La Land  2016.0
# ...        ...                                ...     ...
# 24407  1664306                             Fixerr  2019.0
# 24408  1693420    LSD - Love, Scandal and Doctors  2021.0
# 24409  1702871                            Olessia  2019.0
# 24410  1762425                      Pretty Things  2005.0
# 24411  1835643                       Angela Black  2021.0
#
#                                                 tagline  \
# 0                      She's everything. He's just Ken.
# 1                           Act like you own the place.
# 2      The universe is so much bigger than you realize.
# 3                               Mischief. Mayhem. Soap.
# 4                        Here's to the fools who dream.
# ...                                                 ...
# 24407                                               NaN
# 24408                                               NaN
# 24409                                               NaN
# 24410                                               NaN
# 24411                 Push something enough, it breaks.
#
#                                              description  minute  rating  \
# 0      Barbie and Ken are having the time of their li...   114.0    3.86
# 1      All unemployed, Ki-taek's family takes peculia...   133.0    4.56
# 2      An aging Chinese immigrant is swept up in an i...   140.0    4.30
# 3      A ticking-time-bomb insomniac and a slippery s...   139.0    4.27
# 4      Mia, an aspiring actress, serves lattes to mov...   129.0    4.09
# ...                                                  ...     ...     ...
# 24407  ATS Officer Jayveer Malik’s stands suspended a...   324.0     NaN
# 24408  Love, Scandal and Doctors is a story of 5 medi...   300.0     NaN
# 24409  Film with a soundtrack featuring G. Venugopal ...     NaN     NaN
# 24410  A look into the world of 20th century burlesqu...    90.0     NaN
# 24411  Angela Black leads a seemingly idyllic life wi...   270.0     NaN
#
#                                                    theme  \
# 0      Humanity and the world around us, Crude humor ...
# 1      Humanity and the world around us, Intense viol...
# 2      Humanity and the world around us, Moving relat...
# 3      Intense violence and sexual transgression, Hum...
# 4      Song and dance, Humanity and the world around ...
# ...                                                  ...
# 24407  Thrillers and murder mysteries, High speed and...
# 24408  Thrillers and murder mysteries, High speed and...
# 24409  Song and dance, Dazzling vocal performances an...
# 24410    Song and dance, Erotic relationships and desire
# 24411  Crime, drugs and gangsters, Suspenseful crime ...
#
#                                             genre  \
# 0                               Comedy, Adventure
# 1                         Comedy, Thriller, Drama
# 2      Science Fiction, Adventure, Comedy, Action
# 3                                           Drama
# 4                   Drama, Comedy, Music, Romance
# ...                                           ...
# 24407                                       Drama
# 24408                              Drama, Mystery
# 24409                                       Drama
# 24410                                 Documentary
# 24411                                       Drama
#
#                                       tagged_description  \
# 0      1000001 Barbie and Ken are having the time of ...
# 1      1000002 All unemployed, Ki-taek's family takes...
# 2      1000003 An aging Chinese immigrant is swept up...
# 3      1000004 A ticking-time-bomb insomniac and a sl...
# 4      1000005 Mia, an aspiring actress, serves latte...
# ...                                                  ...
# 24407  1664306 ATS Officer Jayveer Malik’s stands sus...
# 24408  1693420 Love, Scandal and Doctors is a story o...
# 24409  1702871 Film with a soundtrack featuring G. Ve...
# 24410  1762425 A look into the world of 20th century ...
# 24411  1835643 Angela Black leads a seemingly idyllic...
#
#                                    simple_genres
# 0                      ['Escapist', 'Feel-good']
# 1      ['Emotional', 'Feel-good', 'Suspenseful']
# 2                      ['Escapist', 'Feel-good']
# 3                                  ['Emotional']
# 4         ['Emotional', 'Artistic', 'Feel-good']
# ...                                          ...
# 24407                              ['Emotional']
# 24408               ['Emotional', 'Suspenseful']
# 24409                              ['Emotional']
# 24410                            ['Educational']
# 24411                              ['Emotional']
#
# [24412 rows x 11 columns]

# %%
from tqdm import tqdm

for i in tqdm(range(len(movies))):
    ids.append(movies["id"][i])
    sentences = movies["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 24412/24412 [36:49<00:00, 11.05it/s]

# %%
movies["description"][23156]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\movie-recommender\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 23156
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 movies["description"][23156]
#
# File ~\PycharmProjects\movie-recommender\.venv\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\PycharmProjects\movie-recommender\.venv\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~\PycharmProjects\movie-recommender\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 23156

# %%
emotions_df = pd.DataFrame(emotion_scores)
# print(emotions_df)
# print(len(ids))
emotions_df["id"] = ids
emotions_df
# Out:
#           anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0      0.064134  0.104007  0.051363  0.737157  0.549477  0.111690  0.078765
# 1      0.064134  0.104007  0.051363  0.040564  0.549477  0.304677  0.088714
# 2      0.120102  0.104007  0.212463  0.040564  0.549477  0.111690  0.152938
# 3      0.107869  0.104007  0.904958  0.040564  0.800969  0.111690  0.078765
# 4      0.064134  0.104007  0.967849  0.040564  0.549477  0.111690  0.078765
# ...         ...       ...       ...       ...       ...       ...       ...
# 24407  0.682494  0.144579  0.026709  0.080378  0.892373  0.894916  0.398169
# 24408  0.453025  0.497322  0.026341  0.014087  0.454776  0.191987  0.071671
# 24409  0.007377  0.008226  0.005747  0.452469  0.908463  0.048569  0.207229
# 24410  0.008809  0.016056  0.012568  0.643105  0.863761  0.020441  0.072019
# 24411  0.412266  0.104007  0.499489  0.418043  0.549477  0.490536  0.078765
#
#             id
# 0      1000001
# 1      1000002
# 2      1000003
# 3      1000004
# 4      1000005
# ...        ...
# 24407  1664306
# 24408  1693420
# 24409  1702871
# 24410  1762425
# 24411  1835643
#
# [24412 rows x 8 columns]

# %%
# movies = pd.merge(movies, emotions_df, on = "id")
# movies = movies.drop(["surprise_y", "sadness_y", "neutral_y"], axis=1)
movies
# Out:
#             id                               name    date  \
# 0      1000001                             Barbie  2023.0
# 1      1000002                           Parasite  2019.0
# 2      1000003  Everything Everywhere All at Once  2022.0
# 3      1000004                         Fight Club  1999.0
# 4      1000005                         La La Land  2016.0
# ...        ...                                ...     ...
# 24407  1664306                             Fixerr  2019.0
# 24408  1693420    LSD - Love, Scandal and Doctors  2021.0
# 24409  1702871                            Olessia  2019.0
# 24410  1762425                      Pretty Things  2005.0
# 24411  1835643                       Angela Black  2021.0
#
#                                                 tagline  \
# 0                      She's everything. He's just Ken.
# 1                           Act like you own the place.
# 2      The universe is so much bigger than you realize.
# 3                               Mischief. Mayhem. Soap.
# 4                        Here's to the fools who dream.
# ...                                                 ...
# 24407                                               NaN
# 24408                                               NaN
# 24409                                               NaN
# 24410                                               NaN
# 24411                 Push something enough, it breaks.
#
#                                              description  minute  rating  \
# 0      Barbie and Ken are having the time of their li...   114.0    3.86
# 1      All unemployed, Ki-taek's family takes peculia...   133.0    4.56
# 2      An aging Chinese immigrant is swept up in an i...   140.0    4.30
# 3      A ticking-time-bomb insomniac and a slippery s...   139.0    4.27
# 4      Mia, an aspiring actress, serves lattes to mov...   129.0    4.09
# ...                                                  ...     ...     ...
# 24407  ATS Officer Jayveer Malik’s stands suspended a...   324.0     NaN
# 24408  Love, Scandal and Doctors is a story of 5 medi...   300.0     NaN
# 24409  Film with a soundtrack featuring G. Venugopal ...     NaN     NaN
# 24410  A look into the world of 20th century burlesqu...    90.0     NaN
# 24411  Angela Black leads a seemingly idyllic life wi...   270.0     NaN
#
#                                                    theme  \
# 0      Humanity and the world around us, Crude humor ...
# 1      Humanity and the world around us, Intense viol...
# 2      Humanity and the world around us, Moving relat...
# 3      Intense violence and sexual transgression, Hum...
# 4      Song and dance, Humanity and the world around ...
# ...                                                  ...
# 24407  Thrillers and murder mysteries, High speed and...
# 24408  Thrillers and murder mysteries, High speed and...
# 24409  Song and dance, Dazzling vocal performances an...
# 24410    Song and dance, Erotic relationships and desire
# 24411  Crime, drugs and gangsters, Suspenseful crime ...
#
#                                             genre  \
# 0                               Comedy, Adventure
# 1                         Comedy, Thriller, Drama
# 2      Science Fiction, Adventure, Comedy, Action
# 3                                           Drama
# 4                   Drama, Comedy, Music, Romance
# ...                                           ...
# 24407                                       Drama
# 24408                              Drama, Mystery
# 24409                                       Drama
# 24410                                 Documentary
# 24411                                       Drama
#
#                                       tagged_description  \
# 0      1000001 Barbie and Ken are having the time of ...
# 1      1000002 All unemployed, Ki-taek's family takes...
# 2      1000003 An aging Chinese immigrant is swept up...
# 3      1000004 A ticking-time-bomb insomniac and a sl...
# 4      1000005 Mia, an aspiring actress, serves latte...
# ...                                                  ...
# 24407  1664306 ATS Officer Jayveer Malik’s stands sus...
# 24408  1693420 Love, Scandal and Doctors is a story o...
# 24409  1702871 Film with a soundtrack featuring G. Ve...
# 24410  1762425 A look into the world of 20th century ...
# 24411  1835643 Angela Black leads a seemingly idyllic...
#
#                                    simple_genres     anger   disgust  \
# 0                      ['Escapist', 'Feel-good']  0.064134  0.104007
# 1      ['Emotional', 'Feel-good', 'Suspenseful']  0.064134  0.104007
# 2                      ['Escapist', 'Feel-good']  0.120102  0.104007
# 3                                  ['Emotional']  0.107869  0.104007
# 4         ['Emotional', 'Artistic', 'Feel-good']  0.064134  0.104007
# ...                                          ...       ...       ...
# 24407                              ['Emotional']  0.682494  0.144579
# 24408               ['Emotional', 'Suspenseful']  0.453025  0.497322
# 24409                              ['Emotional']  0.007377  0.008226
# 24410                            ['Educational']  0.008809  0.016056
# 24411                              ['Emotional']  0.412266  0.104007
#
#            fear       joy   sadness  surprise   neutral
# 0      0.051363  0.737157  0.549477  0.111690  0.078765
# 1      0.051363  0.040564  0.549477  0.304677  0.088714
# 2      0.212463  0.040564  0.549477  0.111690  0.152938
# 3      0.904958  0.040564  0.800969  0.111690  0.078765
# 4      0.967849  0.040564  0.549477  0.111690  0.078765
# ...         ...       ...       ...       ...       ...
# 24407  0.026709  0.080378  0.892373  0.894916  0.398169
# 24408  0.026341  0.014087  0.454776  0.191987  0.071671
# 24409  0.005747  0.452469  0.908463  0.048569  0.207229
# 24410  0.012568  0.643105  0.863761  0.020441  0.072019
# 24411  0.499489  0.418043  0.549477  0.490536  0.078765
#
# [24412 rows x 18 columns]

# %%
movies.to_csv("movies_with_emotions.csv", index = False)
